# %% [markdown]
# # GEOG 682 Lab 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Crime_2017.csv')

# %%
df
# Out:
#                                                 wkt_geom       CCN     DATE  \
# 0      Point (-77.02498381736047861 38.89981322477427...  17099955  6/12/17
# 1      Point (-77.07098904595119393 38.90769465590191...  17099960  6/12/17
# 2      Point (-77.04663978712287076 38.9091032074190295)  17099975  6/12/17
# 3      Point (-77.0097061689589566 38.96372943312384507)  17099979  6/12/17
# 4      Point (-77.02886695677204898 38.89523608044212...  17099985  6/12/17
# ...                                                  ...       ...      ...
# 33064  Point (-77.0364509361627654 38.93826676860488334)  17143727  8/20/17
# 33065  Point (-76.99952951670918821 38.91687770443352...  17143735  8/20/17
# 33066  Point (-77.02757277028815963 38.91700056846330...  17143753  8/20/17
# 33067  Point (-77.00613700409942908 38.9199944263221056)  17143768  8/20/17
# 33068  Point (-76.93579572234675368 38.90670766508154...  17128811  7/31/17
#
#           SHIFT  METHOD       OFFENSE  \
# ...

# %%
df.columns
# Out:
# Index(['wkt_geom', 'CCN', 'DATE', 'SHIFT', 'METHOD', 'OFFENSE', 'BLOCK',
#        'XBLOCK', 'YBLOCK', 'WARD', 'ANC', 'DISTRICT', 'PSA', 'NEIGHBORHO',
#        'BLOCK_GROU', 'CENSUS_TRA', 'VOTING_PRE', 'LATITUDE', 'LONGITUDE',
#        'BID', 'START_DATE', 'END_DATE', 'OBJECTID'],
#       dtype='object')

# %%
df_jan = df[df['DATE'].between('1/1/17','1/31/17')]

# %%
df_jan
# Out:
#                                                 wkt_geom       CCN     DATE  \
# 4125   Point (-76.97520530990401255 38.89949797330820...  17400003   1/3/17
# 4126   Point (-77.07099037687268606 38.95536663435888...  17400006   1/3/17
# 4134   Point (-77.01619707608939791 38.94054142056932...  17400041  1/10/17
# 4136   Point (-76.99951820865460661 38.88374495753981...  17400050  1/10/17
# 4137     Point (-77.03902775827423 38.92569934679452359)  17400052  1/10/17
# ...                                                  ...       ...      ...
# 32903  Point (-76.92295558339135653 38.90348392088610...  17013605  1/24/17
# 32904  Point (-77.03261762061751483 38.90453172191855...  17013612  1/24/17
# 32905  Point (-76.9892716340280856 38.88603259563193859)  17013620  1/24/17
# 32906  Point (-77.02440859688346109 38.93697270894023...  17013629  1/24/17
# 32907  Point (-76.9949767478296252 38.88923996351896761)  17013647  1/24/17
#
# ...

# %% [markdown]
# ## 1) 2,496 crimes committed in Janurary

# %%
df_D3 = df[df['DISTRICT'] == 3]

# %%
df_D3
# Out:
#                                                 wkt_geom       CCN     DATE  \
# 5      Point (-77.01829165516194564 38.92204705397512...  17099996  6/12/17
# 25     Point (-77.02838381221395991 38.92673837334142...  17101162  6/14/17
# 26     Point (-77.01893433591266103 38.9103811591353832)  17101172  6/14/17
# 34     Point (-77.03409273984220818 38.9274304876225159)  17101305  6/14/17
# 40     Point (-77.03273284903337981 38.92952080524231...  17109654  6/27/17
# ...                                                  ...       ...      ...
# 33041  Point (-77.02808887377977953 38.90991989127739...  17127460  7/25/17
# 33047  Point (-77.0318524680701131 38.92084603699748158)  17143490  8/20/17
# 33056  Point (-77.03390117215511168 38.91261184373359...  17143593  8/20/17
# 33060  Point (-77.02155335125094382 38.91611901721243...  17143671  8/20/17
# 33066  Point (-77.02757277028815963 38.91700056846330...  17143753  8/20/17
#
#           SHIFT  METHOD                     OFFENSE  \
# ...

# %% [markdown]
# ## 2) 5,434 crimes committed in District 3

# %%
df_D3_Auto = df_D3[df_D3['OFFENSE'] == 'THEFT F/AUTO']

# %%
df_D3_Auto
# Out:
#                                                 wkt_geom       CCN     DATE  \
# 5      Point (-77.01829165516194564 38.92204705397512...  17099996  6/12/17
# 25     Point (-77.02838381221395991 38.92673837334142...  17101162  6/14/17
# 26     Point (-77.01893433591266103 38.9103811591353832)  17101172  6/14/17
# 74     Point (-77.02299834734563433 38.92742418932692...  17095239   6/5/17
# 87     Point (-77.03026851788845875 38.91112646496354...  17095360   6/5/17
# ...                                                  ...       ...      ...
# 32997  Point (-77.03090234742663256 38.91038761488673...  17141405  8/16/17
# 33000  Point (-77.03056595032222731 38.90564931245253...  17141434  8/16/17
# 33011  Point (-77.02460157229643301 38.92797337001602...  17141608  8/16/17
# 33025  Point (-77.02294893756636895 38.91723578476256...  17142327  8/18/17
# 33030  Point (-77.02166039823946164 38.92688394603928...  17142460  8/18/17
#
# ...

# %% [markdown]
# ## 3) 2,337 thefts from autos committed in District 3.

# %%
x = df_D3_Auto['XBLOCK']
y = df_D3_Auto['YBLOCK']

plt.scatter(x, y)
plt.show()
